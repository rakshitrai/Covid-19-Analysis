# %%
# Importing libraries
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Got the file of covid-19 case from this website, 
# Which gets updated everyday https://www.mohfw.gov.in/data/datanew.json'
df=pd.read_json('datanew.json')
# Reading dataset

# %% [markdown]
# ### This above cell was last run on 31-10-2021, The dataset below is as of 31-10-2021.

# %%
df
# Loading dataset
# Out:
#       sno                                state_name  active  positive  \
# 0       2               Andaman and Nicobar Islands       5      7651
# 1       1                            Andhra Pradesh    4837   2065716
# 2       3                         Arunachal Pradesh     108     55143
# 3       4                                     Assam    3791    610150
# 4       5                                     Bihar      45    726085
# 5       6                                Chandigarh      30     65340
# 6       7                              Chhattisgarh     300   1005985
# 7       8  Dadra and Nagar Haveli and Daman and Diu       6     10682
# 8      10                                     Delhi     334   1439788
# 9      11                                       Goa     411    178063
# 10     12                                   Gujarat     192    826526
# 11     13                                   Haryana     133    771229
# 12     14                          Himachal Pradesh    1978    223876
# 13     15                         Jammu and Kashmir     872    332053
# 14     16                                 Jharkhand      93    348736
# 15     17                                 Karnataka    8655   2987694
# 16     18                                 Kerala***   79331   4954063
# 17     19                                    Ladakh      58     20941
# 18     20                               Lakshadweep       0     10365
# 19     21                            Madhya Pradesh     113    792832
# 20     22                               Maharashtra   22084   6609292
# 21     23                                   Manipur     871    123609
# 22     24                                 Meghalaya     482     83559
# 23     25                                   Mizoram    7107    120780
# 24     26                                  Nagaland     222     31811
# 25     27                                    Odisha    4063   1040595
# 26     28                                Puducherry     446    127936
# 27     29                                    Punjab     253    602349
# 28     30                                 Rajasthan      30    954424
# 29     31                                    Sikkim     176     31948
# 30     32                                Tamil Nadu   11850   2700593
# 31     34                                 Telangana    4096    671174
# 32     33                                   Tripura     116     84459
# 33     35                               Uttarakhand     146    343876
# 34     36                             Uttar Pradesh      98   1710133
# 35     37                               West Bengal    8223   1591014
# 36  11111                                            161555  34260470
#
#        cured   death  new_active  new_positive  new_cured  new_death  \
# 0       7517     129           4          7651       7518        129
# 1    2046512   14367        4649       2066065    2047047      14369
# 2      54755     280         109         55154      54765        280
# 3     600367    5992        3699        610433     600738       5996
# 4     716379    9661          48        726090     716381       9661
# 5      64490     820          34         65346      64492        820
# 6     992110   13575         317       1006020     992127      13576
# 7      10672       4           6         10682      10672          4
# 8    1414363   25091         349       1439825    1414385      25091
# 9     174289    3363         382        178085     174339       3364
# 10    816246   10088         208        826557     816260      10089
# 11    761047   10049         134        771241     761058      10049
# 12    218150    3748        2056        224021     218212       3753
# 13    326749    4432         886        332154     326836       4432
# 14    343505    5138         106        348754     343510       5138
# 15   2940978   38061        8737       2988041    2941233      38071
# 16   4843576   31156       79234       4961490    4850742      31514
# 17     20675     208          65         20951      20678        208
# 18     10314      51           0         10365      10314         51
# 19    782195   10524         107        792838     782207      10524
# 20   6447038  140170       20524       6609906    6449186     140196
# 21    120819    1919         708        123668     121040       1920
# 22     81628    1449         461         83605      81695       1449
# 23    113246     427        6926        121359     114002        431
# 24     30905     684         222         31831      30925        684
# 25   1028207    8325        3943       1040969    1028697       8329
# 26    125633    1857         437        127975     125681       1857
# 27    585539   16557         251        602375     585566      16558
# 28    945440    8954          32        954427     945441       8954
# 29     31377     395         183         31958      31380        395
# 30   2652660   36083       11685       2701614    2653832      36097
# 31    663124    3954        4072        671342     663315       3955
# 32     83527     816         126         84471      83529        816
# 33    336330    7400         155        343891     336336       7400
# 34   1687135   22900         107       1710152    1687145      22900
# 35   1563678   19113        8310       1591994    1564558      19126
# 36  33641175  457740      159272      34273300   33655842     458186
#
#    state_code
# 0          35
# 1          28
# 2          12
# 3          18
# 4          10
# 5          04
# 6          22
# 7          26
# 8          07
# 9          30
# 10         24
# 11         06
# 12         02
# 13         01
# 14         20
# 15         29
# 16         32
# 17         37
# 18         31
# 19         23
# 20         27
# 21         14
# 22         17
# 23         15
# 24         13
# 25         21
# 26         34
# 27         03
# 28         08
# 29         11
# 30         33
# 31         36
# 32         16
# 33         05
# 34         09
# 35         19
# 36

# %% [markdown]
# ### DataUnderstanding

# %%
df.shape
# There are 37 rows and 11 columns
# Out:
# (37, 11)

# %%
df.isnull().sum()
# no null values
# Out:
# sno             0
# state_name      0
# active          0
# positive        0
# cured           0
# death           0
# new_active      0
# new_positive    0
# new_cured       0
# new_death       0
# state_code      0
# dtype: int64

# %%
df.info()
# type of data present in the columns(int,object)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sno           37 non-null     int64
#  1   state_name    37 non-null     object
#  2   active        37 non-null     int64
#  3   positive      37 non-null     int64
#  4   cured         37 non-null     int64
#  5   death         37 non-null     int64
#  6   new_active    37 non-null     int64
#  7   new_positive  37 non-null     int64
#  8   new_cured     37 non-null     int64
#  9   new_death     37 non-null     int64
#  10  state_code    37 non-null     object
# dtypes: int64(9), object(2)
# memory usage: 3.3+ KB

# %%
df.describe()
# Viewing the descriptive statistics of the data like mean, std deviation, min and max values present in the dataset
# Out:
#                 sno         active      positive         cured          death  \
# count     37.000000      37.000000  3.700000e+01  3.700000e+01      37.000000
# mean     319.054054    8732.702703  1.851917e+06  1.818442e+06   24742.702703
# std     1823.499245   29093.018428  5.652564e+06  5.549028e+06   76951.109856
# min        1.000000       0.000000  7.651000e+03  7.517000e+03       4.000000
# 25%       11.000000     108.000000  8.445900e+04  8.352700e+04     820.000000
# 50%       20.000000     300.000000  6.023490e+05  5.855390e+05    5992.000000
# 75%       29.000000    4063.000000  1.040595e+06  1.028207e+06   14367.000000
# max    11111.000000  161555.000000  3.426047e+07  3.364118e+07  457740.000000
#
#           new_active  new_positive     new_cured      new_death
# count      37.000000  3.700000e+01  3.700000e+01      37.000000
# mean     8609.297297  1.852611e+06  1.819235e+06   24766.810811
# std     28736.495521  5.654726e+06  5.551511e+06   77022.667266
# min         0.000000  7.651000e+03  7.518000e+03       4.000000
# 25%       107.000000  8.447100e+04  8.352900e+04     820.000000
# 50%       317.000000  6.023750e+05  5.855660e+05    5996.000000
# 75%      3943.000000  1.040969e+06  1.028697e+06   14369.000000
# max    159272.000000  3.427330e+07  3.365584e+07  458186.000000

# %%
df.keys()
# Displaying all the column names present in data
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death', 'state_code'],
#       dtype='object')

# %%
df.columns
# Different code but same purpose as above that is displaying all column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death', 'state_code'],
#       dtype='object')

# %%
df.nunique()
# The nunique() function is used to count distinct observations over requested axis. It returns Series with number of distinct observations.
# Out:
# sno             37
# state_name      37
# active          36
# positive        37
# cured           37
# death           37
# new_active      36
# new_positive    37
# new_cured       37
# new_death       37
# state_code      37
# dtype: int64

# %%
df.tail()
# As we can see there is an extra row in the end that may be the total of that column
# Out:
#       sno     state_name  active  positive     cured   death  new_active  \
# 32     33        Tripura     116     84459     83527     816         126
# 33     35    Uttarakhand     146    343876    336330    7400         155
# 34     36  Uttar Pradesh      98   1710133   1687135   22900         107
# 35     37    West Bengal    8223   1591014   1563678   19113        8310
# 36  11111                 161555  34260470  33641175  457740      159272
#
#     new_positive  new_cured  new_death state_code
# 32         84471      83529        816         16
# 33        343891     336336       7400         05
# 34       1710152    1687145      22900         09
# 35       1591994    1564558      19126         19
# 36      34273300   33655842     458186

# %%
df=df.iloc[:36]
# we apply the iloc function and select all rows except the last row

# %%
df.tail()
# This is the dataset that we are to work on
# Out:
#     sno     state_name  active  positive    cured  death  new_active  \
# 31   34      Telangana    4096    671174   663124   3954        4072
# 32   33        Tripura     116     84459    83527    816         126
# 33   35    Uttarakhand     146    343876   336330   7400         155
# 34   36  Uttar Pradesh      98   1710133  1687135  22900         107
# 35   37    West Bengal    8223   1591014  1563678  19113        8310
#
#     new_positive  new_cured  new_death state_code
# 31        671342     663315       3955         36
# 32         84471      83529        816         16
# 33        343891     336336       7400         05
# 34       1710152    1687145      22900         09
# 35       1591994    1564558      19126         19

# %%
df['active'].sum(axis = 0) 
# The total number of active cases in India is 2,22,526
# Out:
# 161555

# %%
df['positive'].sum(axis = 0) 
# The total number of positive cases in India are 10,466,595
# Out:
# 34260470

# %%
df['cured'].sum(axis = 0)
# The total number of cured cases in India is 10,092,909
# Out:
# 33641175

# %%
df['death'].sum(axis = 0)
# The total number of deaths in India are 1,51,160
# Out:
# 457740

# %%
df['new_active'].sum(axis = 0)
# The total number of new active cases are 2,16,558
# Out:
# 159272

# %%
df['new_positive'].sum(axis = 0)
# The total number of new positive cases are 10,479,179
# Out:
# 34273300

# %%
df['new_cured'].sum(axis = 0)
# The total number of new cured cases are 10,111,294
# Out:
# 33655842

# %%
df['new_death'].sum(axis = 0)
# The total number of new death cases are 1,51,327
# Out:
# 458186

# %% [markdown]
# ### Data Visualization

# %%
sns.pairplot(data=df)
# plotting scatter plots of all data using pairplot

# %%
cases_df=df.sum()
# Storing total cases in cases_df

# %%
cases_df
# Subset of original dataset
# Out:
# sno                                                           694
# state_name      Andaman and Nicobar IslandsAndhra PradeshAruna...
# active                                                     161555
# positive                                                 34260470
# cured                                                    33641175
# death                                                      457740
# new_active                                                 159272
# new_positive                                             34273300
# new_cured                                                33655842
# new_death                                                  458186
# state_code      3528121810042226073024060201202932373123271417...
# dtype: object

# %%
cases_df.drop(['sno','state_name','state_code'],inplace=True)
# Dropping unnecessary columns

# %%
cases_df
# Name of case types and their total number
# Out:
# active            161555
# positive        34260470
# cured           33641175
# death             457740
# new_active        159272
# new_positive    34273300
# new_cured       33655842
# new_death         458186
# dtype: object

# %%
my_data = [161555,34260470,33641175,457740]
my_labels = 'Active','Positive','Cured','Death'
my_explode = (0,0,0,1.5)
my_colors = ['blue','yellow','green','red']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
cases_df
# Name of case types and their total number
# Out:
# active            161555
# positive        34260470
# cured           33641175
# death             457740
# new_active        159272
# new_positive    34273300
# new_cured       33655842
# new_death         458186
# dtype: object

# %%
my_data = [159272,34273300,33655842,458186]
my_labels = 'New Active','New Positive','New Cured','New Death'
my_explode = (0,0,0,1.5)
my_colors = ['blue','yellow','green','red']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
my_data = [161555,34260470,33641175,457740,159272,34273300,33655842,458186]
my_labels = 'Active','Positive','Cured','Death','New Active','New Positive','New Cured','New Death'
my_explode = (0.5,0,0,1.5,0.5,0,0,1.5)
my_colors = ['gray','navajowhite','blanchedalmond','grey','lightblue','papayawhip','moccasin','lightpink']
fig1, ax1 = plt.subplots(figsize=(20, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
plt.rcParams['figure.figsize']=(13,8)
# giving figure size

# %%
df[['state_name','active']].groupby(["state_name"]).mean().sort_values(by='active').plot.bar(color='purple')
plt.show()
# We can also use the groupby function to sort values in an ascending order based on the x-axis, y-axis and its keys
# Below we get a clear picture of the states in an increasing order based on their active level of cases.
# Kerela has a higher active cases compared to other states

# %%
df[['state_name','death']].groupby(["state_name"]).mean().sort_values(by='death').plot.bar(color='purple')
plt.show()
# We can also use the groupby function to sort values in an ascending order based on the x-axis, y-axis and its keys
# Below we get a clear picture of the states in an increasing order based on their death cases.
# Maharashtra has a higher death cases compared to other states

# %%
df.columns
# Displaying column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death', 'state_code'],
#       dtype='object')

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='active',color='lightgreen',data=df);
# The visualization below shows us that high number of active cases are found in kerala followed by maharashtra

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='positive',color='teal',data=df);
# The below visualization shows us that high number of positive cases can be seen in Maharashtra followed by karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='cured',color='blue',data=df);
# The visualization below shows us that high number of people have cured in the state of Maharashtra followed by karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='death',color='teal',data=df);
# The below visualization shows us that high number of deaths taking place in the state of Maharashtra followed by Tamilnadu and karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_active',color='teal',data=df);
# The following visualization shows us the total number of new cases and kerela has the high number of new active cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_positive',color='teal',data=df);
# The following visualization shows us the total number of new positive cases and Maharashtra has the high number of new positive cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_cured',color='teal',data=df);
# The following visualization shows us the total number of new cured cases and Maharashtra has the high number of new cured cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_death',color='teal',data=df);
# Maharashtra has the highest new death rates in India followed by Karnataka

# %%
df.columns
# column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death', 'state_code'],
#       dtype='object')

# %%
df.drop(['sno','state_code'],axis=1,inplace=True)
# we have dropped columns like sno and statecode
# Out:
# C:\Users\Rakshit\anaconda3\lib\site-packages\pandas\core\frame.py:4308: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
df.head(5)
# This is the resulting data
# Out:
#                     state_name  active  positive    cured  death  new_active  \
# 0  Andaman and Nicobar Islands       5      7651     7517    129           4
# 1               Andhra Pradesh    4837   2065716  2046512  14367        4649
# 2            Arunachal Pradesh     108     55143    54755    280         109
# 3                        Assam    3791    610150   600367   5992        3699
# 4                        Bihar      45    726085   716379   9661          48
#
#    new_positive  new_cured  new_death
# 0          7651       7518        129
# 1       2066065    2047047      14369
# 2         55154      54765        280
# 3        610433     600738       5996
# 4        726090     716381       9661

# %%
df=df.set_index('state_name')
# Setting index as statename

# %%
df.head(5)
# Out:
#                              active  positive    cured  death  new_active  \
# state_name
# Andaman and Nicobar Islands       5      7651     7517    129           4
# Andhra Pradesh                 4837   2065716  2046512  14367        4649
# Arunachal Pradesh               108     55143    54755    280         109
# Assam                          3791    610150   600367   5992        3699
# Bihar                            45    726085   716379   9661          48
#
#                              new_positive  new_cured  new_death
# state_name
# Andaman and Nicobar Islands          7651       7518        129
# Andhra Pradesh                    2066065    2047047      14369
# Arunachal Pradesh                   55154      54765        280
# Assam                              610433     600738       5996
# Bihar                              726090     716381       9661

# %%
df.plot.barh(stacked=True,figsize=(13,8))
# Stacked bar plot
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
df1=df[['cured', 'death']] 
df1.plot.barh(color={"cured": "purple", "death": "black"},figsize=(13,8))
# bar plot for cured and death
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
df2=df[['positive', 'death']] 
df2.plot.barh(color={"positive": "aquamarine", "death": "orange"},figsize=(13,8))
# bar plot for positive cases and death rate
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
df3=df[['death', 'cured']] 
df3.plot.barh(color={"death": "red", "cured": "grey"},figsize=(13,8))
# barplot for death cases and cured cases
# Out:
# <AxesSubplot:ylabel='state_name'>

# %%
df4=df[['active', 'death']] 
df4.plot.barh(color={"active": "black", "death": "orange"},figsize=(13,8))
# bar plot for active and death cases
# Out:
# <AxesSubplot:ylabel='state_name'>
